# %%
from functions import *

def train_deep_model(model,X_train, y_train, X_val, y_val, BATCH_SIZE, EPOCHS, plot, callback,model_name):
    # load pre-trained word embeddings into an Embedding layer
    # the trainable parameter is set to False so as to keep the embeddings fixed
    if callback is True:
        logdir = os.path.join("logs/"+str(model_name))        
        tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
        cm_callback = keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

        history = model.fit(X_train,
                  to_categorical(y_train),
                  batch_size=BATCH_SIZE,
                  epochs=EPOCHS,
                  validation_data=(X_val,to_categorical(y_val)),
                  callbacks=[tensorboard_callback,cm_callback])
        
    else:
        history = model.fit(X_train,
                  to_categorical(y_train),
                  batch_size=BATCH_SIZE,
                  epochs=EPOCHS,
                  validation_data=(X_val,to_categorical(y_val)))

    if plot is True:
        fig,(ax) = plt.subplots(1, 2, figsize=(13,4))
        ax[0].set_title("Training and Validation Accuracy")
        ax[0].plot(history.history['loss'], label='loss')
        ax[0].plot(history.history['val_loss'], label='val_loss')
        ax[0].legend(loc='upper right')

        ax[1].set_title("Training and Validation Accuracy")
        ax[1].plot(history.history['accuracy'], label='acc')
        ax[1].plot(history.history['val_accuracy'], label='val_acc')
        ax[1].legend(loc='lower right')
        plt.show()
    return model
    
def plot_confusion_matrix(cm):
    #class_names = ["Negative","Positive"]
    #class_names = ["Negative","Neutral","Positive"]
    class_names = ["Very Negative","Negative","Neutral","Positive", "Very Positive"]
    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Compute the labels from the normalized confusion matrix.
    labels = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, labels[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure
      
def plot_to_image(figure):
    # Save the plot to a PNG in memory.
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    # Convert PNG buffer to TF image
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    # Add the batch dimension
    image = tf.expand_dims(image, 0)
    return image

def log_confusion_matrix(epoch, logs):
  # Use the model to predict the values from the validation dataset.
    test_pred_raw = model.predict(X_val)
    test_pred = np.argmax(test_pred_raw, axis=1)
    # Calculate the confusion matrix.
    cm = sklearn.metrics.confusion_matrix(y_val, test_pred)
    # Log the confusion matrix as an image summary.
    figure = plot_confusion_matrix(cm)
    cm_image = plot_to_image(figure)
    logdir = os.path.join("logs/"+str(model_name))        
    file_writer_cm = tf.summary.create_file_writer(logdir + '/cm')
    # Log the confusion matrix as an image summary.
    with file_writer_cm.as_default():
        tf.summary.image("Confusion Matrix", cm_image, step=epoch)

# %% [markdown]
# # 1- Data Loading and visualisation

# %%
# ----------------------------- IMDB 4 scale  -----------------------------------------
df_submission = load_sub_data()
df_submission = df_submission
df_train = load_train_data()
df_train = df_train


# df_submission = df_submission[0:1000]
# df_train=df_train[0:1000]

# %%
df_train
# Out:
#                                                    review  sentiment
# 0       a series of escapades demonstrating the adage ...          1
# 1       a series of escapades demonstrating the adage ...          2
# 2                                                a series          2
# 3                                                       a          2
# 4                                                  series          2
# ...                                                   ...        ...
# 156055                                           hearst s          2
# 156056                          forced avuncular chortles          1
# 156057                                 avuncular chortles          3
# 156058                                          avuncular          2
# 156059                                           chortles          2
#
# [156060 rows x 2 columns]

# %%
plot_class_distribution(df_train["sentiment"])
# Out:
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: sentiment, dtype: int64

# %% [markdown]
# # 2- Data pre-processing

# %% [markdown]
# ### Data cleaning

# %%
df_train = data_cleaning(df_train)
df_submission = data_cleaning(df_submission)

# %% [markdown]
# ### Transformation to TF-IDF features

# %%
# best_par = return_best_tfidf(df_train)

# %%
# X_TfIdf = Tfidf_transformation(df_train,ngram_range=(1,1))
# # X_TfIdf = Tfidf_transformation(df_train,ngram_range= best_par["tfidf__ngram_range"])

# %% [markdown]
# ### Transformation to word2Vec features using gensim

# %%
# # X_word2Vec2 = load_pkl("./X_word2Vec.pkl")
X_word2Vec = word2Vec_transform(df_train,True)
# Out:
# 100% |########################################################################|

# %% [markdown]
# # 3- Data partitionning

# %% [markdown]
# ### Create sets using the original data

# %%
X_train,X_val,X_test,y_train,y_val,y_test = data_partitioning(df_train["review"].values,df_train["sentiment"].values,test_size=0.3,summary=True)
# Out:
# Overall class distribution in this dataset
# 2    55700
# 3    23034
# 1    19102
# 4     6449
# 0     4956
# dtype: int64
# 2    11939
# 3     4894
# 1     4101
# 4     1380
# 0     1095
# dtype: int64
#
# X_train has shape: (109241,)
# y_train has shape: (109241,)
# X_val has shape: (23409,)
# y_val has shape: (23409,)
# X_test has shape: (23410,)
# y_test has shape: (23410,)

# %% [markdown]
# ### Create sets to be used when converted into TFIDF features

# %%
X_train_TfIdf,X_val_TfIdf,X_test_TfIdf,y_train_TfIdf,y_val_TfIdf,y_test_TfIdf = data_partitioning(X_TfIdf,df_train["sentiment"].values,test_size=0.3,summary=False)

# %% [markdown]
# ### Create sets to be used when converted into Word2Vec features

# %%
X_train_word2Vec,X_val_word2Vec,X_test_word2Vec,y_train_word2Vec,y_val_word2Vec,y_test_word2Vec= data_partitioning(X_word2Vec,df_train["sentiment"].values,test_size=0.3, summary=False)

# %% [markdown]
# ### Create sets to be used when converted into BERT features

# %%
X_train_bert,X_val_bert,X_test_bert,y_train_bert,y_val_bert,y_test_bert = data_partitioning(df_train["review"].values,df_train["sentiment"].values,test_size=0.3,summary=False)

# %% [markdown]
# # 4- Inference step using Logistic regression

# %% [markdown]
# ### Sentiment prediction using TF-IDF embeddings

# %%
# LR_predict(X_train_TfIdf,y_train_TfIdf,X_test_TfIdf,y_test_TfIdf)

# %% [markdown]
# ### Dimensionality reduction using Truncated Singular Value Decomposition (TSVD)

# %%
# X_train_TfIdf,X_test_TfIdf,tsvd = apply_TSVD(X_train_TfIdf,X_test_TfIdf,True,500)

# %% [markdown]
# ### Sentiment prediction using TF-IDF embeddings after diemnsionality reduction

# %%
# LR_predict(X_train_TfIdf,y_train_TfIdf,X_test_TfIdf,y_test_TfIdf)

# %% [markdown]
# ### Sentiment prediction using Word2Vec embeddings

# %%
# LR_predict(X_train_word2Vec,y_train_word2Vec,X_test_word2Vec,y_test_word2Vec)

# %% [markdown]
# # 5- Inference step using Deep Learning

# %% [markdown]
# ### Data encoding and embedding layer creation with Word2vec Transfer Learning

# %%
EMBEDDING_DIM,MAX_SEQUENCE_LENGTH,MAX_VOCAB_SIZE,w2v_model,embedding_matrix,X_train,X_val,X_test,X_submission = load_pretrained_embedding_model(df_train,
                                                                                                                                   df_submission, 
                                                                                                                                   X_train, 
                                                                                                                                   X_val,
                                                                                                                                   X_test,
                                                                                                                                   EMBEDDING_DIM = 300, 
                                                                                                                                   model = 'word2vec-google-news-300')
# Out:
# Maximum sentence lenght:  43
# Found 653 unique tokens in the dataset.
# Loading word vectors from local file...
# Shape of X_train data tensor: (699, 43)
# Shape of X_val data tensor: (150, 43)
# Shape of X_test data tensor: (151, 43)
# Shape of X_submission data tensor: (1000, 43)
# Filling pre-trained embeddings...
# The final embedding matrix has shape:  (654, 300)

# %%
embedding_layer = Embedding(MAX_VOCAB_SIZE,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %% [markdown]
# ## 1- Long-Short-Term-Memory (LSTM)

# %%
def simple_LSTM_model_multiclass(embedding_layer):
    simple_LSTM_model_multiclass = Sequential()
    simple_LSTM_model_multiclass.add(embedding_layer)
    simple_LSTM_model_multiclass.add(LSTM(128))
    simple_LSTM_model_multiclass.add(Dense(5, activation='softmax'))
    simple_LSTM_model_multiclass.compile(loss='categorical_crossentropy', 
#                                          optimizer='adam', 
                                         optimizer=Adam(lr=1e-3),
                                         metrics=['accuracy'])
    simple_LSTM_model_multiclass.summary()
    return simple_LSTM_model_multiclass,"simple_LSTM_model_multiclass"

model, model_name = simple_LSTM_model_multiclass(embedding_layer)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 43, 300)           196200
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               219648
# _________________________________________________________________
# dense (Dense)                (None, 5)                 645
# =================================================================
# Total params: 416,493
# Trainable params: 220,293
# Non-trainable params: 196,200
# _________________________________________________________________

# %%
model = train_deep_model(model,
                        X_train,y_train, 
                        X_val, y_val,
                        BATCH_SIZE = 128, 
                        EPOCHS = 10, 
                        plot=True,
                        callback=False,
                        model_name= model_name)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 3s 306ms/step - loss: 1.5730 - accuracy: 0.3902 - val_loss: 1.3763 - val_accuracy: 0.7133
# Epoch 2/10
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3178 - accuracy: 0.6965 - val_loss: 1.0486 - val_accuracy: 0.7133
# Epoch 3/10
# 6/6 [==============================] - 1s 101ms/step - loss: 1.0619 - accuracy: 0.6872 - val_loss: 0.9950 - val_accuracy: 0.7133
# Epoch 4/10
# 6/6 [==============================] - 1s 94ms/step - loss: 0.9614 - accuracy: 0.6970 - val_loss: 0.9086 - val_accuracy: 0.7133
# Epoch 5/10
# 6/6 [==============================] - 1s 100ms/step - loss: 0.9409 - accuracy: 0.6741 - val_loss: 0.8784 - val_accuracy: 0.7133
# Epoch 6/10
# 6/6 [==============================] - 1s 99ms/step - loss: 0.8901 - accuracy: 0.6791 - val_loss: 0.8591 - val_accuracy: 0.7133
# Epoch 7/10
# 6/6 [==============================] - 1s 94ms/step - loss: 0.8530 - accuracy: 0.6732 - val_loss: 0.8430 - val_accuracy: 0.7267
# Epoch 8/10
# 6/6 [==============================] - 1s 92ms/step - loss: 0.8386 - accuracy: 0.6766 - val_loss: 0.8281 - val_accuracy: 0.7133
# Epoch 9/10
# 6/6 [==============================] - 1s 92ms/step - loss: 0.7844 - accuracy: 0.6913 - val_loss: 0.8271 - val_accuracy: 0.7000
# Epoch 10/10
# 6/6 [==============================] - 1s 123ms/step - loss: 0.7794 - accuracy: 0.7096 - val_loss: 0.8174 - val_accuracy: 0.7133

# %%
generate_pred(model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.40      0.22      0.29        27
#            2       0.65      0.96      0.77        90
#            3       1.00      0.12      0.21        26
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.63       151
#    macro avg       0.41      0.26      0.25       151
# weighted avg       0.63      0.63      0.55       151

# %%
submission = generate_submission(model,X_submission,df_submission,model_name,False)
submission
# Out:
#      PhraseId  Sentiment
# 0      156061          2
# 1      156062          2
# 2      156063          2
# 3      156064          2
# 4      156065          2
# ..        ...        ...
# 995    157056          2
# 996    157057          2
# 997    157058          2
# 998    157059          2
# 999    157060          2
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## 2- BiLSTM with a Dense Layer and Dropout

# %%
def simple_biLSTM_model_multiclass(embedding_layer):
    simple_biLSTM_model_multiclass = Sequential()
    simple_biLSTM_model_multiclass.add(embedding_layer)
    simple_biLSTM_model_multiclass.add(Bidirectional(LSTM(128)))
    simple_biLSTM_model_multiclass.add(Dense(128, activation='relu'))
    simple_biLSTM_model_multiclass.add(Dropout(0.5))
    simple_biLSTM_model_multiclass.add(Dense(5, activation='softmax'))
    simple_biLSTM_model_multiclass.compile(loss='categorical_crossentropy', 
#                                          optimizer='adam', 
                                           optimizer=Adam(lr=1e-3),
                                           metrics=['accuracy'])
    
    simple_biLSTM_model_multiclass.summary()
    return simple_biLSTM_model_multiclass,"simple_biLSTM_model_multiclass"

model, model_name = simple_biLSTM_model_multiclass(embedding_layer)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 43, 300)           196200
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               439296
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 669,037
# Trainable params: 472,837
# Non-trainable params: 196,200
# _________________________________________________________________

# %%
model = train_deep_model(model,
                        X_train,y_train, 
                        X_val, y_val,
                        BATCH_SIZE = 128, 
                        EPOCHS = 11, 
                        plot=True,
                        callback=False,
                        model_name= model_name )
# Out:
# Epoch 1/11
# 6/6 [==============================] - 4s 310ms/step - loss: 1.5672 - accuracy: 0.4253 - val_loss: 1.3567 - val_accuracy: 0.7133
# Epoch 2/11
# 6/6 [==============================] - 1s 122ms/step - loss: 1.2954 - accuracy: 0.6909 - val_loss: 1.0095 - val_accuracy: 0.7133
# Epoch 3/11
# 6/6 [==============================] - 1s 128ms/step - loss: 1.0667 - accuracy: 0.6806 - val_loss: 0.9137 - val_accuracy: 0.7000
# Epoch 4/11
# 6/6 [==============================] - 1s 150ms/step - loss: 0.9604 - accuracy: 0.6639 - val_loss: 0.8708 - val_accuracy: 0.7067
# Epoch 5/11
# 6/6 [==============================] - 1s 123ms/step - loss: 0.9110 - accuracy: 0.6750 - val_loss: 0.8337 - val_accuracy: 0.7133
# Epoch 6/11
# 6/6 [==============================] - 1s 126ms/step - loss: 0.8201 - accuracy: 0.6974 - val_loss: 0.7962 - val_accuracy: 0.7067
# Epoch 7/11
# 6/6 [==============================] - 1s 132ms/step - loss: 0.7604 - accuracy: 0.7129 - val_loss: 0.7706 - val_accuracy: 0.7067
# Epoch 8/11
# 6/6 [==============================] - 1s 167ms/step - loss: 0.7309 - accuracy: 0.7251 - val_loss: 0.7769 - val_accuracy: 0.7400
# Epoch 9/11
# 6/6 [==============================] - 1s 121ms/step - loss: 0.6860 - accuracy: 0.7402 - val_loss: 0.7646 - val_accuracy: 0.7200
# Epoch 10/11
# 6/6 [==============================] - 1s 161ms/step - loss: 0.6758 - accuracy: 0.7367 - val_loss: 0.8045 - val_accuracy: 0.7267
# Epoch 11/11
# 6/6 [==============================] - 1s 135ms/step - loss: 0.5883 - accuracy: 0.7774 - val_loss: 0.8145 - val_accuracy: 0.7200

# %%
generate_pred(model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.41      0.52      0.46        27
#            2       0.74      0.83      0.78        90
#            3       0.67      0.38      0.49        26
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.66       151
#    macro avg       0.36      0.35      0.35       151
# weighted avg       0.63      0.66      0.63       151

# %%
submission = generate_submission(model,X_submission,df_submission,model_name,False)
submission
# Out:
#      PhraseId  Sentiment
# 0      156061          1
# 1      156062          1
# 2      156063          2
# 3      156064          1
# 4      156065          1
# ..        ...        ...
# 995    157056          2
# 996    157057          2
# 997    157058          2
# 998    157059          2
# 999    157060          2
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## 3- Multiple layer lstm

# %%
def multi_layer_lstm_multiclass(embedding_layer):
    multi_layer_lstm_multiclass = Sequential()
    multi_layer_lstm_multiclass.add(embedding_layer)
    multi_layer_lstm_multiclass.add(Bidirectional(LSTM(128, return_sequences=True)))
    keras.layers.Dropout(0.5)
    multi_layer_lstm_multiclass.add(GlobalMaxPool1D())
    keras.layers.Dropout(0.5)
    multi_layer_lstm_multiclass.add(Dense(5, activation='softmax'))
    multi_layer_lstm_multiclass.compile(loss='categorical_crossentropy', 
#                                          optimizer='adam', 
                                           optimizer=Adam(lr=1e-3),
                                           metrics=['accuracy'])
    
    multi_layer_lstm_multiclass.summary()
    return multi_layer_lstm_multiclass,"multi_layer_lstm_multiclass"

model, model_name = multi_layer_lstm_multiclass(embedding_layer)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 43, 300)           196200
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 43, 256)           439296
# _________________________________________________________________
# global_max_pooling1d (Global (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 636,781
# Trainable params: 440,581
# Non-trainable params: 196,200
# _________________________________________________________________

# %%
model = train_deep_model(model,
                        X_train,y_train, 
                        X_val, y_val,
                        BATCH_SIZE = 128, 
                        EPOCHS = 13, 
                        plot=True,
                        callback=False,
                        model_name= model_name )
# Out:
# Epoch 1/13
# 6/6 [==============================] - 4s 265ms/step - loss: 1.5589 - accuracy: 0.4894 - val_loss: 1.3862 - val_accuracy: 0.7133
# Epoch 2/13
# 6/6 [==============================] - 1s 119ms/step - loss: 1.3386 - accuracy: 0.6809 - val_loss: 1.0540 - val_accuracy: 0.7133
# Epoch 3/13
# 6/6 [==============================] - 1s 124ms/step - loss: 1.0768 - accuracy: 0.6779 - val_loss: 0.9839 - val_accuracy: 0.7133
# Epoch 4/13
# 6/6 [==============================] - 1s 130ms/step - loss: 0.9876 - accuracy: 0.6734 - val_loss: 0.9175 - val_accuracy: 0.7133
# Epoch 5/13
# 6/6 [==============================] - 1s 127ms/step - loss: 0.9326 - accuracy: 0.6697 - val_loss: 0.8837 - val_accuracy: 0.7133
# Epoch 6/13
# 6/6 [==============================] - 1s 133ms/step - loss: 0.9353 - accuracy: 0.6709 - val_loss: 0.8871 - val_accuracy: 0.7133
# Epoch 7/13
# 6/6 [==============================] - 1s 128ms/step - loss: 0.8641 - accuracy: 0.6914 - val_loss: 0.8506 - val_accuracy: 0.7267
# Epoch 8/13
# 6/6 [==============================] - 1s 178ms/step - loss: 0.8207 - accuracy: 0.7027 - val_loss: 0.8343 - val_accuracy: 0.7333
# Epoch 9/13
# 6/6 [==============================] - 1s 150ms/step - loss: 0.7908 - accuracy: 0.7175 - val_loss: 0.8321 - val_accuracy: 0.7200
# Epoch 10/13
# 6/6 [==============================] - 1s 147ms/step - loss: 0.7715 - accuracy: 0.7183 - val_loss: 0.8096 - val_accuracy: 0.7200
# Epoch 11/13
# 6/6 [==============================] - 1s 142ms/step - loss: 0.7591 - accuracy: 0.7059 - val_loss: 0.7992 - val_accuracy: 0.7200
# Epoch 12/13
# 6/6 [==============================] - 1s 136ms/step - loss: 0.6814 - accuracy: 0.7449 - val_loss: 0.7781 - val_accuracy: 0.7267
# Epoch 13/13
# 6/6 [==============================] - 1s 135ms/step - loss: 0.6343 - accuracy: 0.7784 - val_loss: 0.7844 - val_accuracy: 0.7067

# %%
generate_pred(model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.35      0.26      0.30        27
#            2       0.66      0.93      0.77        90
#            3       1.00      0.15      0.27        26
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.63       151
#    macro avg       0.40      0.27      0.27       151
# weighted avg       0.63      0.63      0.56       151

# %%
submission = generate_submission(model,X_submission,df_submission,model_name,False)
submission
# Out:
#      PhraseId  Sentiment
# 0      156061          2
# 1      156062          2
# 2      156063          2
# 3      156064          2
# 4      156065          2
# ..        ...        ...
# 995    157056          2
# 996    157057          2
# 997    157058          2
# 998    157059          2
# 999    157060          2
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## 4- Convolutional Neural network

# %%
def simple_CNN_multiclass(embedding_layer):
    simple_CNN_multiclass = Sequential()
    simple_CNN_multiclass.add(embedding_layer)
    simple_CNN_multiclass.add(Conv1D(filters=100, kernel_size=2, padding='valid', activation='relu', strides=1))
    simple_CNN_multiclass.add(GlobalMaxPool1D())
    simple_CNN_multiclass.add(Dense(256, activation='relu'))
    simple_CNN_multiclass.add(Dense(5, activation='softmax'))
    simple_CNN_multiclass.compile(loss='categorical_crossentropy', 
#                                          optimizer='adam', 
                                           optimizer=Adam(lr=1e-3),
                                           metrics=['accuracy'])
    
    simple_CNN_multiclass.summary()
    return simple_CNN_multiclass,"simple_CNN_multiclass"

model, model_name = simple_CNN_multiclass(embedding_layer)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 43, 300)           196200
# _________________________________________________________________
# conv1d (Conv1D)              (None, 42, 100)           60100
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               25856
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 283,441
# Trainable params: 87,241
# Non-trainable params: 196,200
# _________________________________________________________________

# %%
model = train_deep_model(model,
                        X_train,y_train, 
                        X_val, y_val,
                        BATCH_SIZE = 128, 
                        EPOCHS = 13, 
                        plot=True,
                        callback=False,
                        model_name= model_name )
# Out:
# Epoch 1/13
# 6/6 [==============================] - 1s 52ms/step - loss: 1.5442 - accuracy: 0.3972 - val_loss: 1.2369 - val_accuracy: 0.7133
# Epoch 2/13
# 6/6 [==============================] - 0s 92ms/step - loss: 1.2180 - accuracy: 0.6821 - val_loss: 1.1081 - val_accuracy: 0.7133
# Epoch 3/13
# 6/6 [==============================] - 0s 25ms/step - loss: 1.1165 - accuracy: 0.6665 - val_loss: 1.0421 - val_accuracy: 0.7133
# Epoch 4/13
# 6/6 [==============================] - 0s 25ms/step - loss: 1.0309 - accuracy: 0.6787 - val_loss: 1.0023 - val_accuracy: 0.7133
# Epoch 5/13
# 6/6 [==============================] - 0s 28ms/step - loss: 0.9561 - accuracy: 0.6683 - val_loss: 0.9316 - val_accuracy: 0.7133
# Epoch 6/13
# 6/6 [==============================] - 0s 26ms/step - loss: 0.8351 - accuracy: 0.6965 - val_loss: 0.8783 - val_accuracy: 0.7200
# Epoch 7/13
# 6/6 [==============================] - 0s 28ms/step - loss: 0.7750 - accuracy: 0.7239 - val_loss: 0.8393 - val_accuracy: 0.7133
# Epoch 8/13
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6994 - accuracy: 0.7522 - val_loss: 0.8113 - val_accuracy: 0.7333
# Epoch 9/13
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5925 - accuracy: 0.7868 - val_loss: 0.7774 - val_accuracy: 0.7333
# Epoch 10/13
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5501 - accuracy: 0.8015 - val_loss: 0.7825 - val_accuracy: 0.7400
# Epoch 11/13
# 6/6 [==============================] - 0s 61ms/step - loss: 0.4975 - accuracy: 0.8052 - val_loss: 0.7702 - val_accuracy: 0.7667
# Epoch 12/13
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4673 - accuracy: 0.8142 - val_loss: 0.7898 - val_accuracy: 0.7533
# Epoch 13/13
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4195 - accuracy: 0.8396 - val_loss: 0.7788 - val_accuracy: 0.7533

# %%
generate_pred(model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.50      0.37      0.43        27
#            2       0.74      0.90      0.81        90
#            3       0.71      0.58      0.64        26
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.70       151
#    macro avg       0.39      0.37      0.37       151
# weighted avg       0.65      0.70      0.67       151

# %%
submission = generate_submission(model,X_submission,df_submission,model_name,False)
submission
# Out:
#      PhraseId  Sentiment
# 0      156061          3
# 1      156062          3
# 2      156063          2
# 3      156064          2
# 4      156065          3
# ..        ...        ...
# 995    157056          1
# 996    157057          1
# 997    157058          2
# 998    157059          2
# 999    157060          2
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## 5- ELABORATED CNN WITH PARALLEL LAYERS AND DROPOUT

# %%
def parallelized_CNN_multiclass(embedding_layer):
    input_ = Input(shape=(MAX_SEQUENCE_LENGTH,))
    tweet_encoder = embedding_layer(input_)
    bigram_branch = Conv1D(filters=100, kernel_size=2, padding='valid', activation='relu', strides=1)(tweet_encoder)
    bigram_branch = GlobalMaxPool1D()(bigram_branch)
    trigram_branch = Conv1D(filters=100, kernel_size=3, padding='valid', activation='relu', strides=1)(tweet_encoder)
    trigram_branch = GlobalMaxPool1D()(trigram_branch)
    fourgram_branch = Conv1D(filters=100, kernel_size=4, padding='valid', activation='relu', strides=1)(tweet_encoder)
    fourgram_branch = GlobalMaxPool1D()(fourgram_branch)
    fifthgram_branch = Conv1D(filters=100, kernel_size=5, padding='valid', activation='relu', strides=1)(tweet_encoder)
    fifthgram_branch = GlobalMaxPool1D()(fifthgram_branch)
    merged = concatenate([bigram_branch, trigram_branch,fourgram_branch,fifthgram_branch], axis=1)
    merged = Dropout(0.5)(merged)
    merged = Dense(5)(merged)
    output = Activation('softmax')(merged)
    parallelized_CNN_multiclass = Model(inputs=[input_], outputs=[output])

    parallelized_CNN_multiclass.compile(loss='categorical_crossentropy', 
#                                          optimizer='adam', 
                                           optimizer=Adam(lr=1e-3),
                                           metrics=['accuracy'])
    
    parallelized_CNN_multiclass.summary()
    return parallelized_CNN_multiclass,"parallelized_CNN_multiclass"

model, model_name = parallelized_CNN_multiclass(embedding_layer)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 43)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 43, 300)      196200      input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 42, 100)      60100       embedding[4][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 41, 100)      90100       embedding[4][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 40, 100)      120100      embedding[4][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 39, 100)      150100      embedding[4][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 100)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 100)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 100)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 100)          0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 400)          0           global_max_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_3[0][0]
#                                                                  global_max_pooling1d_4[0][0]
#                                                                  global_max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 400)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 5)            2005        dropout_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 5)            0           dense_6[0][0]
# ==================================================================================================
# Total params: 618,605
# Trainable params: 422,405
# Non-trainable params: 196,200
# __________________________________________________________________________________________________

# %%
model = train_deep_model(model,
                        X_train,y_train, 
                        X_val, y_val,
                        BATCH_SIZE = 128, 
                        EPOCHS = 13, 
                        plot=True,
                        callback=False,
                        model_name= model_name )
# Out:
# Epoch 1/13
# 6/6 [==============================] - 1s 169ms/step - loss: 1.5441 - accuracy: 0.3779 - val_loss: 1.1630 - val_accuracy: 0.7133
# Epoch 2/13
# 6/6 [==============================] - 0s 62ms/step - loss: 1.1394 - accuracy: 0.6817 - val_loss: 1.0513 - val_accuracy: 0.7200
# Epoch 3/13
# 6/6 [==============================] - 1s 108ms/step - loss: 0.9675 - accuracy: 0.7016 - val_loss: 0.9663 - val_accuracy: 0.7333
# Epoch 4/13
# 6/6 [==============================] - 0s 66ms/step - loss: 0.8556 - accuracy: 0.7367 - val_loss: 0.8973 - val_accuracy: 0.7400
# Epoch 5/13
# 6/6 [==============================] - 0s 71ms/step - loss: 0.7609 - accuracy: 0.7473 - val_loss: 0.8594 - val_accuracy: 0.7267
# Epoch 6/13
# 6/6 [==============================] - 0s 71ms/step - loss: 0.7024 - accuracy: 0.7440 - val_loss: 0.8298 - val_accuracy: 0.7333
# Epoch 7/13
# 6/6 [==============================] - 0s 64ms/step - loss: 0.6024 - accuracy: 0.8112 - val_loss: 0.8072 - val_accuracy: 0.7333
# Epoch 8/13
# 6/6 [==============================] - 0s 63ms/step - loss: 0.5804 - accuracy: 0.7761 - val_loss: 0.7880 - val_accuracy: 0.7333
# Epoch 9/13
# 6/6 [==============================] - 1s 107ms/step - loss: 0.5246 - accuracy: 0.8088 - val_loss: 0.7681 - val_accuracy: 0.7267
# Epoch 10/13
# 6/6 [==============================] - 0s 69ms/step - loss: 0.5094 - accuracy: 0.8232 - val_loss: 0.7583 - val_accuracy: 0.7400
# Epoch 11/13
# 6/6 [==============================] - 0s 68ms/step - loss: 0.4504 - accuracy: 0.8402 - val_loss: 0.7527 - val_accuracy: 0.7467
# Epoch 12/13
# 6/6 [==============================] - 0s 79ms/step - loss: 0.4370 - accuracy: 0.8439 - val_loss: 0.7510 - val_accuracy: 0.7400
# Epoch 13/13
# 6/6 [==============================] - 0s 72ms/step - loss: 0.4465 - accuracy: 0.8340 - val_loss: 0.7571 - val_accuracy: 0.7333

# %%
generate_pred(model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.53      0.30      0.38        27
#            2       0.71      0.97      0.82        90
#            3       0.92      0.42      0.58        26
#            4       1.00      0.25      0.40         4
#
#     accuracy                           0.71       151
#    macro avg       0.63      0.39      0.44       151
# weighted avg       0.70      0.71      0.67       151

# %%
submission = generate_submission(model,X_submission,df_submission,model_name,False)
submission
# Out:
#      PhraseId  Sentiment
# 0      156061          2
# 1      156062          2
# 2      156063          2
# 3      156064          2
# 4      156065          2
# ..        ...        ...
# 995    157056          2
# 996    157057          2
# 997    157058          2
# 998    157059          2
# 999    157060          2
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## 6- Hybrid model: CNN-LSTM

# %%
def hybrid_LSTM_CNN_multiclass(embedding_layer):
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,))
    embedded_sequences = embedding_layer(sequence_input)
    drop_out_1 = Dropout(0.5, name='drop_out_1')(embedded_sequences)
    biLSTM_1 = Bidirectional(LSTM(60, return_sequences=True))(embedded_sequences)
    conv_1 = Conv1D(128, 2, activation='relu', name='conv_1')(biLSTM_1)
    gmp_1 = GlobalMaxPool1D(name='gmp_1')(conv_1)
    conv_2 = Conv1D(128, 3, activation='relu', name='conv_2')(biLSTM_1)
    gmp_2 = GlobalMaxPool1D(name='gmp_2')(conv_2)
    conv_3 = Conv1D(128, 4, activation='relu', name='conv_3')(biLSTM_1)
    gmp_3 = GlobalMaxPool1D(name='gmp_3')(conv_3)

    concat = concatenate([gmp_1,gmp_2,gmp_3])
    # concat = concatenate([gmp_1,gmp_2])

    drop_out_2 = Dropout(0.5, name='drop_out_2')(concat)
    mp_dense = Dense(64, activation='relu', name='mp_dense')(drop_out_2)
    drop_out_3 = Dropout(0.5, name='drop_out_2')(mp_dense)
    
    preds = Dense(5, activation='softmax', name='preds')(mp_dense)
    hybrid_LSTM_CNN_multiclass = Model(sequence_input, preds)

    hybrid_LSTM_CNN_multiclass.compile(loss='categorical_crossentropy', 
#                                          optimizer='adam', 
                                           optimizer=Adam(lr=1e-3),
                                           metrics=['accuracy'])
    
    hybrid_LSTM_CNN_multiclass.summary()
    return hybrid_LSTM_CNN_multiclass,"hybrid_LSTM_CNN_multiclass"

model, model_name = hybrid_LSTM_CNN_multiclass(embedding_layer)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 43)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 43, 300)      196200      input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 43, 120)      173280      embedding[5][0]
# __________________________________________________________________________________________________
# conv_1 (Conv1D)                 (None, 42, 128)      30848       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv1D)                 (None, 41, 128)      46208       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv1D)                 (None, 40, 128)      61568       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# gmp_1 (GlobalMaxPooling1D)      (None, 128)          0           conv_1[0][0]
# __________________________________________________________________________________________________
# gmp_2 (GlobalMaxPooling1D)      (None, 128)          0           conv_2[0][0]
# __________________________________________________________________________________________________
# gmp_3 (GlobalMaxPooling1D)      (None, 128)          0           conv_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384)          0           gmp_1[0][0]
#                                                                  gmp_2[0][0]
#                                                                  gmp_3[0][0]
# __________________________________________________________________________________________________
# drop_out_2 (Dropout)            (None, 384)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# mp_dense (Dense)                (None, 64)           24640       drop_out_2[0][0]
# __________________________________________________________________________________________________
# preds (Dense)                   (None, 5)            325         mp_dense[0][0]
# ==================================================================================================
# Total params: 533,069
# Trainable params: 336,869
# Non-trainable params: 196,200
# __________________________________________________________________________________________________

# %%
model = train_deep_model(model,
                        X_train,y_train, 
                        X_val, y_val,
                        BATCH_SIZE = 128, 
                        EPOCHS = 13, 
                        plot=True,
                        callback=False,
                        model_name= model_name )
# Out:
# Epoch 1/13
# 6/6 [==============================] - 4s 231ms/step - loss: 1.5616 - accuracy: 0.3781 - val_loss: 1.3089 - val_accuracy: 0.7133
# Epoch 2/13
# 6/6 [==============================] - 1s 92ms/step - loss: 1.2798 - accuracy: 0.6854 - val_loss: 1.0813 - val_accuracy: 0.7133
# Epoch 3/13
# 6/6 [==============================] - 1s 99ms/step - loss: 1.1211 - accuracy: 0.6721 - val_loss: 0.9560 - val_accuracy: 0.7133
# Epoch 4/13
# 6/6 [==============================] - 1s 95ms/step - loss: 0.9602 - accuracy: 0.6828 - val_loss: 0.8718 - val_accuracy: 0.7200
# Epoch 5/13
# 6/6 [==============================] - 1s 97ms/step - loss: 0.8833 - accuracy: 0.6867 - val_loss: 0.8337 - val_accuracy: 0.7200
# Epoch 6/13
# 6/6 [==============================] - 1s 134ms/step - loss: 0.8651 - accuracy: 0.6833 - val_loss: 0.8290 - val_accuracy: 0.7267
# Epoch 7/13
# 6/6 [==============================] - 1s 91ms/step - loss: 0.7991 - accuracy: 0.7074 - val_loss: 0.7858 - val_accuracy: 0.7333
# Epoch 8/13
# 6/6 [==============================] - 1s 98ms/step - loss: 0.7388 - accuracy: 0.7229 - val_loss: 0.7654 - val_accuracy: 0.7067
# Epoch 9/13
# 6/6 [==============================] - 1s 94ms/step - loss: 0.6482 - accuracy: 0.7658 - val_loss: 0.7664 - val_accuracy: 0.7400
# Epoch 10/13
# 6/6 [==============================] - 1s 91ms/step - loss: 0.6546 - accuracy: 0.7511 - val_loss: 0.7392 - val_accuracy: 0.7600
# Epoch 11/13
# 6/6 [==============================] - 1s 95ms/step - loss: 0.5642 - accuracy: 0.7836 - val_loss: 0.7606 - val_accuracy: 0.7267
# Epoch 12/13
# 6/6 [==============================] - 1s 98ms/step - loss: 0.5419 - accuracy: 0.7982 - val_loss: 0.7447 - val_accuracy: 0.7600
# Epoch 13/13
# 6/6 [==============================] - 1s 93ms/step - loss: 0.4952 - accuracy: 0.8030 - val_loss: 0.7192 - val_accuracy: 0.7733

# %%
generate_pred(model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.50      0.30      0.37        27
#            2       0.73      0.91      0.81        90
#            3       0.68      0.58      0.62        26
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.70       151
#    macro avg       0.38      0.36      0.36       151
# weighted avg       0.64      0.70      0.66       151

# %%
submission = generate_submission(model,X_submission,df_submission,model_name,False)
submission
# Out:
#      PhraseId  Sentiment
# 0      156061          2
# 1      156062          2
# 2      156063          2
# 3      156064          2
# 4      156065          2
# ..        ...        ...
# 995    157056          2
# 996    157057          2
# 997    157058          2
# 998    157059          2
# 999    157060          2
#
# [1000 rows x 2 columns]

# %% [markdown]
# # TRANSFORMERS

# %%
module_url = "https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1"
bert_layer = hub.KerasLayer(module_url, trainable=True)
# Out:
# Using /var/folders/vn/v6m1j6cj1ds_74czjy2wp1mh0000gn/T/tfhub_modules to cache modules.
# Downloading TF-Hub Module 'https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1'.
# Downloading https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1: 410.00MB
# Downloading https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1: 900.00MB
# Downloading https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1: 1.25GB
# Downloaded https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1, Total size: 1.26GB
# Downloaded TF-Hub Module 'https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1'.

# %%
vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()

# %%
tokenizer = tokenization.FullTokenizer(vocab_file, do_lower_case)

# %%
def build_model(bert_layer, max_len=MAX_SEQUENCE_LENGTH):
    input_word_ids = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="input_word_ids")
    input_mask = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="input_mask")
    segment_ids = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="segment_ids")

    pooled_output, sequence_output = bert_layer([input_word_ids, input_mask, segment_ids])
    clf_output = sequence_output[:, 0, :]
    net = tf.keras.layers.Dense(64, activation='relu')(clf_output)
    net = tf.keras.layers.Dropout(0.2)(net)
    net = tf.keras.layers.Dense(32, activation='relu')(net)
    net = tf.keras.layers.Dropout(0.2)(net)
    out = tf.keras.layers.Dense(5, activation='softmax')(net)
    
    model = tf.keras.models.Model(inputs=[input_word_ids, input_mask, segment_ids], outputs=out)
    model.compile(tf.keras.optimizers.Adam(lr=1e-5), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    
    model.summary()
    return model, "bert_model"

# %%
# train_input = bert_encode(X_train.values, tokenizer, max_len=150)
# val_input = bert_encode(X_val.values, tokenizer, max_len=150)
# test_input = bert_encode(X_test.values, tokenizer, max_len=150)
# sub_input = bert_encode(df_submission.review.values, tokenizer, max_len=150)

# new_model = tf.keras.models.load_model('../input/test-models/model.h5',custom_objects={'KerasLayer':hub.KerasLayer})
# new_model.summary()

# %%
train_input = bert_encode(X_train_bert, tokenizer, max_len=MAX_SEQUENCE_LENGTH)
val_input = bert_encode(X_val_bert, tokenizer, max_len=MAX_SEQUENCE_LENGTH)
test_input = bert_encode(X_test_bert, tokenizer, max_len=MAX_SEQUENCE_LENGTH)
sub_input = bert_encode(df_submission.review.values, tokenizer, max_len=MAX_SEQUENCE_LENGTH)

# %%
model,model_name = build_model(bert_layer, max_len=MAX_SEQUENCE_LENGTH)

# bert_model = tf.keras.models.load_model('../input/test-models/model.h5',custom_objects={'KerasLayer':hub.KerasLayer})
# bert_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_word_ids (InputLayer)     [(None, 43)]         0
# __________________________________________________________________________________________________
# input_mask (InputLayer)         [(None, 43)]         0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 43)]         0
# __________________________________________________________________________________________________
# keras_layer (KerasLayer)        [(None, 1024), (None 335141889   input_word_ids[0][0]
#                                                                  input_mask[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 1024)         0           keras_layer[0][1]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           65600       tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           2080        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 5)            165         dropout_5[0][0]
# ==================================================================================================
# Total params: 335,209,734
# Trainable params: 335,209,733
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %%
model = train_bert_model(model,
                        train_input,y_train_bert, 
                        val_input,y_val_bert,
                        BATCH_SIZE = 200, 
                        EPOCHS = 2, 
                        plot=True,
                        callback=True,
                        model_name= model_name)
# Out:
# Epoch 1/2
# 2/4 [==============>...............] - ETA: 4:36 - loss: 1.6668 - accuracy: 0.1700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-72d5c6ec178b> in <module>
#       6                         plot=True,
#       7                         callback=True,
# ----> 8                         model_name= model_name)
#
# ~/Desktop/AMLSII_final_assignment/functions.py in train_bert_model(model, X_train, y_train, X_val, y_val, BATCH_SIZE, EPOCHS, plot, callback, model_name)
#     466                   epochs=EPOCHS,
#     467                   validation_data=(X_val,to_categorical(y_val)),
# --> 468                   callbacks=[checkpoint,earlystopping])
#     469
#     470     else:
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
generate_pred(model,test_input,y_test_bert)

# %%
submission = generate_submission(model,sub_input,df_submission,model_name,False)
submission
